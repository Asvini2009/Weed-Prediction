# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
path = "/content/HPT - YoloV8x.csv"
data = pd.read_csv(path)
data.head()
# Out:
#    Epochs/ Learning_rate  0.0001  0.0005  0.001  0.005   0.01
# 0                     50   0.737   0.748  0.747  0.712  0.607
# 1                     60   0.727   0.733  0.751  0.723  0.638
# 2                     70   0.704   0.727  0.746  0.744  0.614
# 3                     80   0.741   0.745  0.761  0.703  0.349
# 4                     90   0.725   0.742  0.763  0.710  0.364

# %%
epochs = list(data["Epochs/ Learning_rate"])
lr = list(data.columns)
lr = lr[1:]
all_acc = []
for index in range(len(epochs)):
  all_acc.append(list(data.iloc[index,1:]))
plt.figure(figsize = (9,9))
for index in range(len(epochs)):
  plt.plot(lr, all_acc[index], label = "Epochs: {}".format(epochs[index]))
plt.xlabel("Learning Rate")
plt.ylabel("Accuracy")
plt.title("Accuracy values with Learning rate and Epochs")
plt.grid(True)
plt.legend(loc = "best")
plt.show()

# %%
data.columns
# Out:
# Index(['Epochs/ Learning_rate', '0.0001', '0.0005', '0.001', '0.005', '0.01'], dtype='object')
