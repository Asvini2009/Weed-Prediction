# %%
! pip install ultralytics

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_yaml = "/content/drive/MyDrive/1:1_Asvini_Thivakaran/Dataset/Weed_Dataset_Yolo_format/data.yaml"

# %%
# define the number of epochs and learning rate
EPOCHS = 60
LEARNING_RATE = 0.0005
! yolo task=segment mode=train model=yolov8n-seg.pt data={data_yaml} optimizer="Adam" lr0={LEARNING_RATE} epochs={EPOCHS} imgsz=640 name=yolov8n_custom
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 6.74M/6.74M [00:00<00:00, 81.7MB/s]
# Ultralytics 8.3.39 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
import shutil
import os
def create_directory(directory_path):
    # Check if the directory exists
    if not os.path.exists(directory_path):
        # If it doesn't exist, create it
        os.makedirs(directory_path)
        print(f"Directory '{directory_path}' created.")
    else:
        print(f"Directory '{directory_path}' already exists.")

# %%
# Specify the directory path you want to check/create
model_name = f'yolov8_best_model_epoch_{EPOCHS}_lr_{LEARNING_RATE}'
model_folder = '/content/drive/MyDrive/1:1_Asvini_Thivakaran/Models'
destination_path = os.path.join(model_folder, model_name)
# Call the function to check and create the directory
create_directory(destination_path)
# IMPORTANT
# define the best model custom data path
source_path = '/content/runs/segment/yolov8n_custom10'
shutil.move(source_path, destination_path)
# Out:
# Directory '/content/drive/MyDrive/1:1_Asvini_Thivakaran/Models/yolov8_best_model_epoch_60_lr_0.0005' already exists.
# '/content/drive/MyDrive/1:1_Asvini_Thivakaran/Models/yolov8_best_model_epoch_60_lr_0.0005/yolov8n_custom10'

# %% [markdown]
# Execute till here, don't execute the last two cells.

# %%
model_path="/content/drive/MyDrive/1:1_Asvini_Thivakaran/Models/yolov8_best_model_epoch_60_lr_0.0005/yolov8n_custom10/weights/best.pt"
! yolo task=segment mode=val model={model_path} data={data_yaml}
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.54 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# YOLOv8n-seg summary (fused): 213 layers, 2,937,369 parameters, 0 gradients, 10.7 GFLOPs
# ...
# 100% 755k/755k [00:00<00:00, 103MB/s]
# val: Scanning /content/drive/.shortcut-targets-by-id/1BaUalnTDy7byGB_il14mFbG_ApoLTUnV/1:1_Asvini_Thivakaran/Dataset/Weed_Dataset_Yolo_format/valid/labels.cache... 200 images, 0 backgrounds, 0 corrupt: 100% 200/200 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 13/13 [00:25<00:00,  1.96s/it]
# ...

# %%
test_data = "/content/drive/MyDrive/1:1_Asvini_Thivakaran/Dataset/Weed_Dataset_Yolo_format/test/images"
! yolo task=segment mode=predict model={model_path} conf=0.05 source={test_data}
# Out:
# Ultralytics 8.3.54 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# YOLOv8n-seg summary (fused): 213 layers, 2,937,369 parameters, 0 gradients, 10.7 GFLOPs
#
# image 1/100 /content/drive/MyDrive/1:1_Asvini_Thivakaran/Dataset/Weed_Dataset_Yolo_format/test/images/20221216-GX010015_frame1040_jpg.rf.cac1b188938eb00fbc4eaed64b43ffc1.jpg: 640x640 33 soy_plants, 9.6ms
# image 2/100 /content/drive/MyDrive/1:1_Asvini_Thivakaran/Dataset/Weed_Dataset_Yolo_format/test/images/20221216-GX010015_frame1140_jpg.rf.277ffa949f09e571c83154fa6e79dd2c.jpg: 640x640 27 soy_plants, 9.4ms
# image 3/100 /content/drive/MyDrive/1:1_Asvini_Thivakaran/Dataset/Weed_Dataset_Yolo_format/test/images/20221216-GX010015_frame1380_jpg.rf.60265e976174466dd9fd23719e67e64b.jpg: 640x640 36 soy_plants, 13.5ms
# ...
